# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import random
from datetime import datetime
from PIL import Image
import numpy as np
import torch
import matplotlib.pyplot as plt

sys.path.append('..')

from src.data.transforms import INFERENCE_TRANSFORMS
from src.modeling.model import HCCLF

# %%
model = HCCLF()

# %%
model.load_state_dict(torch.load("../models/final/model.pt"))

# %%
model.eval().to("cpu")

# %%
# img = Image.open("/Users/alexandrepoupeau/Downloads/example.png")
img = Image.open("/Users/alexandrepoupeau/Downloads/test.png")
# img = Image.fromarray(np.full(shape=(256, 256), fill_value=random.randint(0, 255), dtype=np.uint8))

# %%
img

# %%
tensor: torch.Tensor = INFERENCE_TRANSFORMS(img)

# %%
tensor = tensor.unsqueeze(0)

# %%
tensor.shape

# %%
with torch.no_grad():
    result = model(tensor)

# %%
result.numpy()[0][0]
